# %%
import d2lzh as d2l
from mxnet import gluon, init, nd
from mxnet.gluon import data as gdata, nn
import os
import sys

# %%
net = nn.Sequential()
net.add(nn.Conv2D(96, kernel_size=11, strides=4, activation='relu'),
       nn.MaxPool2D(pool_size=3, strides=2),
       nn.Conv2D(256, kernel_size=5, padding=2, activation='relu'),
       nn.MaxPool2D(pool_size=3, strides=2),
       nn.Conv2D(384, kernel_size=3, padding=1, activation='relu'),
       nn.Conv2D(256, kernel_size=3, padding=1, activation='relu'),
       nn.Conv2D(256, kernel_size=3, padding=1, activation='relu'),
       nn.MaxPool2D(pool_size=3, strides=2),
       nn.Dense(4096, activation='relu' ), nn.Dropout(0.5),
       nn.Dense(4096, activation='relu'), nn.Dropout(0.5),
       nn.Dense(10))

# %%
X = nd.random.uniform(shape=(1, 1, 224, 224))
net.initialize()
for layer in net:
    X = layer(X)
    print(layer.name, 'output shape:\t', X.shape)
# Out:
# conv0 output shape:	 (1, 96, 54, 54)
# pool0 output shape:	 (1, 96, 26, 26)
# conv1 output shape:	 (1, 256, 26, 26)
# pool1 output shape:	 (1, 256, 12, 12)
# conv2 output shape:	 (1, 384, 12, 12)
# conv3 output shape:	 (1, 256, 12, 12)
# conv4 output shape:	 (1, 256, 12, 12)
# pool2 output shape:	 (1, 256, 5, 5)
# dense0 output shape:	 (1, 4096)
# dropout0 output shape:	 (1, 4096)
# dense1 output shape:	 (1, 4096)
# dropout1 output shape:	 (1, 4096)
# dense2 output shape:	 (1, 10)

# %%
lr = 0.01
num_epochs = 100
ctx = d2l.try_gpu()
batch_size = 128
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=224)
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate':lr})
d2l.train_ch5(net, train_iter, test_iter, batch_size, trainer, ctx, num_epochs)
# Out:
# training on gpu(0)
# epoch 1, loss 1.2651, train acc 0.526, test acc 0.753, time 37.9 sec
# epoch 2, loss 0.6457, train acc 0.759, test acc 0.806, time 37.1 sec
# epoch 3, loss 0.5380, train acc 0.801, test acc 0.836, time 37.0 sec
# epoch 4, loss 0.4785, train acc 0.823, test acc 0.853, time 37.2 sec
# epoch 5, loss 0.4347, train acc 0.840, test acc 0.861, time 37.0 sec
# epoch 6, loss 0.4044, train acc 0.852, test acc 0.872, time 38.1 sec
# epoch 7, loss 0.3818, train acc 0.860, test acc 0.869, time 39.1 sec
# epoch 8, loss 0.3597, train acc 0.868, test acc 0.883, time 37.2 sec
# epoch 9, loss 0.3460, train acc 0.873, test acc 0.889, time 37.2 sec
# epoch 10, loss 0.3339, train acc 0.878, test acc 0.887, time 37.4 sec
# epoch 11, loss 0.3210, train acc 0.883, test acc 0.892, time 37.4 sec
# epoch 12, loss 0.3101, train acc 0.887, test acc 0.896, time 37.5 sec
# epoch 13, loss 0.3020, train acc 0.890, test acc 0.899, time 37.3 sec
# epoch 14, loss 0.2914, train acc 0.894, test acc 0.897, time 37.3 sec
# epoch 15, loss 0.2859, train acc 0.897, test acc 0.904, time 37.7 sec
# epoch 16, loss 0.2800, train acc 0.896, test acc 0.901, time 37.7 sec
# epoch 17, loss 0.2708, train acc 0.902, test acc 0.908, time 37.7 sec
# epoch 18, loss 0.2619, train acc 0.904, test acc 0.908, time 37.7 sec
# epoch 19, loss 0.2576, train acc 0.905, test acc 0.908, time 37.6 sec
# epoch 20, loss 0.2515, train acc 0.908, test acc 0.907, time 37.5 sec
# epoch 21, loss 0.2465, train acc 0.909, test acc 0.911, time 37.6 sec
# epoch 22, loss 0.2387, train acc 0.912, test acc 0.911, time 37.4 sec
# epoch 23, loss 0.2350, train acc 0.914, test acc 0.916, time 37.4 sec
# epoch 24, loss 0.2276, train acc 0.916, test acc 0.914, time 37.4 sec
# epoch 25, loss 0.2255, train acc 0.916, test acc 0.914, time 37.5 sec
# epoch 26, loss 0.2180, train acc 0.918, test acc 0.916, time 37.4 sec
# epoch 27, loss 0.2134, train acc 0.920, test acc 0.914, time 37.4 sec
# epoch 28, loss 0.2100, train acc 0.923, test acc 0.918, time 37.5 sec
# epoch 29, loss 0.2027, train acc 0.925, test acc 0.918, time 37.4 sec
# epoch 30, loss 0.1996, train acc 0.926, test acc 0.918, time 37.5 sec
# epoch 31, loss 0.1960, train acc 0.928, test acc 0.916, time 37.4 sec
# epoch 32, loss 0.1897, train acc 0.930, test acc 0.920, time 37.8 sec
# epoch 33, loss 0.1872, train acc 0.930, test acc 0.918, time 37.6 sec
# epoch 34, loss 0.1816, train acc 0.931, test acc 0.918, time 37.6 sec
# epoch 35, loss 0.1760, train acc 0.934, test acc 0.922, time 37.6 sec
# epoch 36, loss 0.1729, train acc 0.936, test acc 0.915, time 37.7 sec
# epoch 37, loss 0.1692, train acc 0.937, test acc 0.921, time 38.2 sec
# epoch 38, loss 0.1631, train acc 0.938, test acc 0.923, time 37.6 sec
# epoch 39, loss 0.1611, train acc 0.940, test acc 0.923, time 37.9 sec
# epoch 40, loss 0.1565, train acc 0.942, test acc 0.924, time 37.7 sec
# epoch 41, loss 0.1516, train acc 0.943, test acc 0.924, time 37.9 sec
# epoch 42, loss 0.1479, train acc 0.944, test acc 0.921, time 37.6 sec
# epoch 43, loss 0.1445, train acc 0.946, test acc 0.924, time 37.5 sec
# epoch 44, loss 0.1403, train acc 0.948, test acc 0.924, time 37.4 sec
# epoch 45, loss 0.1382, train acc 0.948, test acc 0.922, time 37.5 sec
# epoch 46, loss 0.1326, train acc 0.950, test acc 0.924, time 37.9 sec
# epoch 47, loss 0.1278, train acc 0.953, test acc 0.924, time 38.0 sec
# epoch 48, loss 0.1235, train acc 0.954, test acc 0.924, time 37.7 sec
# epoch 49, loss 0.1206, train acc 0.955, test acc 0.924, time 37.8 sec
# epoch 50, loss 0.1178, train acc 0.956, test acc 0.924, time 37.7 sec
# epoch 51, loss 0.1147, train acc 0.957, test acc 0.925, time 37.4 sec
# epoch 52, loss 0.1108, train acc 0.959, test acc 0.925, time 37.5 sec
# epoch 53, loss 0.1073, train acc 0.959, test acc 0.922, time 37.5 sec
# epoch 54, loss 0.1066, train acc 0.960, test acc 0.922, time 37.4 sec
# epoch 55, loss 0.1008, train acc 0.962, test acc 0.928, time 37.5 sec
# epoch 56, loss 0.0969, train acc 0.964, test acc 0.925, time 37.4 sec
# epoch 57, loss 0.0933, train acc 0.964, test acc 0.924, time 37.5 sec
# epoch 58, loss 0.0888, train acc 0.966, test acc 0.925, time 37.5 sec
# epoch 59, loss 0.0869, train acc 0.968, test acc 0.928, time 37.5 sec
# epoch 60, loss 0.0850, train acc 0.968, test acc 0.927, time 37.4 sec
# epoch 61, loss 0.0816, train acc 0.970, test acc 0.928, time 37.6 sec
# epoch 62, loss 0.0766, train acc 0.972, test acc 0.928, time 37.4 sec
# epoch 63, loss 0.0773, train acc 0.972, test acc 0.926, time 37.5 sec
# epoch 64, loss 0.0752, train acc 0.971, test acc 0.927, time 37.5 sec
# epoch 65, loss 0.0701, train acc 0.973, test acc 0.929, time 37.5 sec
# epoch 66, loss 0.0716, train acc 0.974, test acc 0.929, time 37.5 sec
# epoch 67, loss 0.0663, train acc 0.975, test acc 0.929, time 37.4 sec
# epoch 68, loss 0.0642, train acc 0.976, test acc 0.931, time 37.5 sec
# epoch 69, loss 0.0627, train acc 0.977, test acc 0.929, time 37.5 sec
# epoch 70, loss 0.0627, train acc 0.977, test acc 0.927, time 37.5 sec
# epoch 71, loss 0.0586, train acc 0.978, test acc 0.925, time 37.5 sec
# epoch 72, loss 0.0566, train acc 0.979, test acc 0.928, time 37.5 sec
# epoch 73, loss 0.0552, train acc 0.979, test acc 0.930, time 37.5 sec
# epoch 74, loss 0.0512, train acc 0.981, test acc 0.931, time 37.8 sec
# epoch 75, loss 0.0509, train acc 0.981, test acc 0.929, time 37.8 sec
# epoch 76, loss 0.0491, train acc 0.982, test acc 0.926, time 37.9 sec
# epoch 77, loss 0.0478, train acc 0.982, test acc 0.930, time 37.6 sec
# epoch 78, loss 0.0457, train acc 0.983, test acc 0.928, time 37.6 sec
# epoch 79, loss 0.0430, train acc 0.984, test acc 0.928, time 37.5 sec
# epoch 80, loss 0.0428, train acc 0.984, test acc 0.930, time 37.5 sec
# epoch 81, loss 0.0420, train acc 0.985, test acc 0.930, time 37.5 sec
# epoch 82, loss 0.0392, train acc 0.985, test acc 0.929, time 37.4 sec
# epoch 83, loss 0.0393, train acc 0.985, test acc 0.928, time 37.5 sec
# epoch 84, loss 0.0378, train acc 0.986, test acc 0.928, time 37.6 sec
# epoch 85, loss 0.0350, train acc 0.987, test acc 0.928, time 37.5 sec
# epoch 86, loss 0.0362, train acc 0.987, test acc 0.929, time 37.5 sec
# epoch 87, loss 0.0344, train acc 0.987, test acc 0.930, time 37.5 sec
# epoch 88, loss 0.0337, train acc 0.988, test acc 0.928, time 37.5 sec
# epoch 89, loss 0.0318, train acc 0.989, test acc 0.928, time 37.5 sec
# epoch 90, loss 0.0309, train acc 0.989, test acc 0.931, time 37.6 sec
# epoch 91, loss 0.0294, train acc 0.989, test acc 0.929, time 37.5 sec
# epoch 92, loss 0.0297, train acc 0.989, test acc 0.930, time 37.6 sec
# epoch 93, loss 0.0266, train acc 0.990, test acc 0.928, time 37.4 sec
# epoch 94, loss 0.0279, train acc 0.990, test acc 0.930, time 37.6 sec
# epoch 95, loss 0.0260, train acc 0.990, test acc 0.930, time 37.5 sec
# epoch 96, loss 0.0255, train acc 0.991, test acc 0.929, time 37.6 sec
# epoch 97, loss 0.0256, train acc 0.991, test acc 0.927, time 37.5 sec
# epoch 98, loss 0.0222, train acc 0.992, test acc 0.931, time 37.5 sec
# epoch 99, loss 0.0225, train acc 0.992, test acc 0.928, time 37.4 sec
# epoch 100, loss 0.0221, train acc 0.992, test acc 0.929, time 37.5 sec
